# %%
import numpy as np
import matplotlib.pyplot as plt
import imageio.v2 as iio
data = iio.imread('fruit.jpg')
bmg = data[800:1000 ,570:980]
print(data.shape)

iio.imsave('orange.jpg', bmg)
plt.imshow(bmg)
plt.show()
# Out:
# (1427, 2100, 3)

# %%
import numpy as np
import matplotlib.pyplot as plt
import imageio.v2 as iio
import scipy.ndimage as nd
data = iio.imread('fruit.jpg', mode='L')
bdata = nd.shift(data, (100, 25))
plt.imshow(bdata)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import imageio.v2 as iio
import scipy.ndimage as nd

data = iio.imread('fruit.jpg')
print(data.shape)
bdata = nd.zoom(data, (2))
print(bdata.shape)
data2 = nd.zoom(data, (2, 2, 1))
print(data2.shape)
data3 = nd.zoom(data, (0.5,0.9, 1))
plt.imshow(data3)
plt.show()
# Out:
# (1427, 2100, 3)
# (2854, 4200, 6)
# (2854, 4200, 3)

# %%
import numpy as np
import scipy.ndimage as nd
import imageio.v2 as iio
import matplotlib.pylab as plt

data = iio.imread('fruit.jpg')
print(data.shape)

d1 = nd.rotate(data, 20)
plt.imshow(d1)
plt.show()

d2 = nd.rotate(data, 20, reshape=False)
plt.imshow(d2)
plt.show()
# Out:
# (1427, 2100, 3)

# %%
import numpy as np
import scipy.ndimage as nd
import imageio.v2 as iio
import matplotlib.pylab as plt

data = iio.imread('world_cup.jpg', mode='L')
print(data.shape)

d1 = nd.binary_dilation(data)
plt.imshow(d1)
plt.show()

d2 = nd.binary_dilation(data, iterations=3)
plt.imshow(d2)
plt.show()
# Out:
# (309, 515)

# %%
import numpy as np
import scipy.ndimage as nd
import imageio.v2 as iio
import matplotlib.pylab as plt

data = iio.imread('world_cup.jpg', mode='L')
print(data.shape)
V, H = data.shape

M = np.indices((V, H))

d = 5
q = 2 * d * np.random.rand(*M.shape) - d
mp = (M + q).astype(int)
d1 = nd.map_coordinates(data, mp)
plt.imshow(d1)
plt.show()
# Out:
# (309, 515)

# %%
import numpy as np
import scipy.ndimage as nd
import imageio.v2 as iio
import matplotlib.pylab as plt

def GeoFun(outcoord):
    a = 10 * np.cos(outcoord[0]/10.0) + outcoord[0]
    b = 10 * np.cos(outcoord[1]/10.0) + outcoord[1]
    return a, b

data = iio.imread('world_cup.jpg', mode ='L')

d1 = nd.geometric_transform(data, GeoFun)
plt.imshow(d1)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import imageio.v2 as iio
data = iio.imread('fruit.jpg')
bmg = data[1200:2400 ,500:980]
print(data.shape)

iio.imsave('Strawberry.jpg', bmg)
plt.imshow(bmg)
plt.show()
# Out:
# (1427, 2100, 3)

# %%
import numpy as np
import matplotlib.pyplot as plt
import imageio.v2 as iio
import scipy.ndimage as nd
data = iio.imread('fruit.jpg', mode='L')
bdata = nd.shift(data, (50, -30))
plt.imshow(bdata)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import imageio.v2 as iio
import scipy.ndimage as nd

data = iio.imread('fruit.jpg')
print(data.shape)
bdata = nd.zoom(data, (2))
print(bdata.shape)
data2 = nd.zoom(data, (2, 3, 1))
print(data2.shape)
data3 = nd.zoom(data, (0.2,0.6, 1))
plt.imshow(data3)
plt.show()
# Out:
# (1427, 2100, 3)
# (2854, 4200, 6)
# (2854, 6300, 3)

# %%
import numpy as np
import scipy.ndimage as nd
import imageio.v2 as iio
import matplotlib.pylab as plt

data = iio.imread('fruit.jpg')
print(data.shape)

d1 = nd.rotate(data, 45)
plt.imshow(d1)
plt.show()

d2 = nd.rotate(data, 45, reshape=False)
plt.imshow(d2)
plt.show()
# Out:
# (1427, 2100, 3)

# %%
import numpy as np
import scipy.ndimage as nd
import imageio.v2 as iio
import matplotlib.pylab as plt

data = iio.imread('fruit.jpg')
print(data.shape)

d1 = nd.rotate(data, 45)
plt.imshow(d1)
plt.show()

d2 = nd.rotate(data, 45, reshape=True)
plt.imshow(d2)
plt.show()
# Out:
# (1427, 2100, 3)
